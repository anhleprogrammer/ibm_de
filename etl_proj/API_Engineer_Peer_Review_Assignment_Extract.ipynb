# %% [markdown]
# # Data Engineer - Extract API Data

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# *   Collect exchange rate data using an API
# *   Store the data as a CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# ### Call the API
#
# <b> Question 1</b> Using the `requests` library call the endpoint given above and save the text, remember the first few characters of the output:

# %%
# Make API Call
url = "https://api.apilayer.com/exchangerates_data/latest?base=USD&apikey=R9pfM0OkGaBDty2ZHVBYbxX5DLRNXLhS"

# %% [markdown]
# ### Save as DataFrame
#
# <b> Question 2</b>  Using the data gathered turn it into a `pandas` dataframe. The dataframe should have the Currency as the index and `Rate` as their columns. Make sure to drop unnecessary columns.

# %%
# Fetch API, turn the data into a dataframe
request = requests.get(url)
data = request.json()
df_exchangeRate = pd.DataFrame(data)

# %%
#Drop unecessary columns
df_exchangeRate = df_exchangeRate.drop(columns=['success','timestamp', 'base','date'])
df_exchangeRate = df_exchangeRate.reset_index()
df_exchangeRate = df_exchangeRate.rename(columns={'index':'Currency', 'rates':'Rates'})
print(df_exchangeRate)
# Out:
#     Currency        Rates
# 0        AED     3.672968
# 1        AFN    89.000271
# 2        ALL   108.043398
# 3        AMD   391.680463
# 4        ANG     1.803483
# ..       ...          ...
# 165      YER   250.349726
# 166      ZAR    18.273550
# 167      ZMK  9001.196929
# 168      ZMW    19.538043
# 169      ZWL   321.999592
#
# [170 rows x 2 columns]

# %% [markdown]
# ### Load the Data
#
# Using the dataframe save it as a CSV names `exchange_rates_1.csv`.

# %%
# Save the Dataframe
df_exchangeRate.to_csv('exchange_rates_1.csv')

# %% [markdown]
# Your CSV should be in this format with more currencies
#
# |     | Rates      |
# | --- | ---------- |
# | AED | 4.398618   |
# | AFN | 92.917693  |
# | ALL | 123.099093 |
# | AMD | 621.935674 |
# | ANG | 2.149648   |
